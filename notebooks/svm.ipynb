# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import os
import re
import joblib
import ldc.io.hdf5 as h5io
import matplotlib.pyplot as plt
from ldc.lisa.noise import get_noise_model

# %%
def extract_model_info(filename):
    """
    Extracts the model name and version from the filename.
    Example:
        'resolved_Model1_0_MW_DWDs_aa2CE_NSWDs_aa2CE_vkick.h5' -> 'Model 1.0'
        'resolved_Model1_1_MW_DWDs_aa2CE_NSWDs_aa2CE_vkick.h5' -> 'Model 1.1'
    """
    # Regular expression to capture 'Model' followed by a number, an underscore, and another number
    match = re.search(r'resolved_(Model)(\d+)_(\d+)_MW', filename)
    if match:
        model_prefix = match.group(1)      # 'Model'
        model_number = match.group(2)      # e.g., '1'
        model_version = match.group(3)     # e.g., '0', '1'
        # Format as 'Model 1.0', 'Model 1.1', etc.
        formatted_model = f"{model_prefix} {model_number}.{model_version}"
        return formatted_model
    else:
        return 'Unknown'
def process_h5_file(filepath):
    """
    Processes a single .h5 file and extracts the necessary parameters.
    Returns a pandas DataFrame with the extracted data and model information.
    """
    # Extract the model from the filename
    filename = os.path.basename(filepath)
    model = extract_model_info(filename)
    
    cats, units = h5io.load_array(filepath, 'cat')
    
    data = {
        'Name': cats['Name'],
        'Frequency': cats['Frequency'],
        'Amplitude': cats['Amplitude'],
        'FrequencyDerivative': cats['FrequencyDerivative'],
        'SNR': np.sqrt(cats['snr2']),
        'Eccentricity': cats['Eccentricity'],
        'Inclination': cats['Inclination'],
        'Polarization': cats['Polarization'],
        'EclipticLatitude': cats['EclipticLatitude'],
        'EclipticLongitude': cats['EclipticLongitude'],
        'InitialPhase': cats['InitialPhase'],
        'Model': model 
    }
    
    df = pd.DataFrame(data)
    
    return df
def compile_data_from_folder(folder_path):
    """
    Compiles data from all .h5 files in the specified folder into a single DataFrame.
    """
    all_data = []
    
    # List all .h5 files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.h5') and filename.startswith('resolved_'):
            filepath = os.path.join(folder_path, filename)
            try:
                df = process_h5_file(filepath)
                all_data.append(df)
                print(f"Processed file: {filename}")
            except Exception as e:
                print(f"Error processing file {filename}: {e}")
    
    if all_data:
        # Concatenate all DataFrames
        combined_df = pd.concat(all_data, ignore_index=True)
        return combined_df
    else:
        print("No .h5 files found or no data extracted.")
        return pd.DataFrame()  # Return empty DataFrame if no data

# %%
resolved_folder_path = '/Users/irwin/Documents/GitHub/lisa-ml/data/resolved_binaries/'
resolved_df = compile_data_from_folder(resolved_folder_path)
resolved_df['Class'] = resolved_df['Name'].str.extract(r'MW_(DWD|NSWD)')
selected_features = ['Frequency', 'Amplitude', 'FrequencyDerivative', 'SNR', 'Eccentricity']

resolved_df = resolved_df.dropna(subset=selected_features + ['Class'])

# Encode labels: DWD=0, NSWD=1
label_encoder = LabelEncoder()
resolved_df['Class'] = label_encoder.fit_transform(resolved_df['Class'])
resolved_df['Frequency_mHz'] = resolved_df['Frequency'] * 1000
resolved_df['FrequencyDerivative_log10'] = np.log10(resolved_df['FrequencyDerivative'])
resolved_df['EclipticLatitude_sin'] = np.sin(resolved_df['EclipticLatitude'])
resolved_df['Amplitude_log10'] = np.log10(resolved_df['Amplitude'])
resolved_df['Inclination_cos'] = np.cos(resolved_df['Inclination'])


cols_to_remove = ['Frequency', 'FrequencyDerivative', 'EclipticLatitude', 'Amplitude', 'Inclination']
resolved_df.drop(columns=cols_to_remove, inplace=True)
# Out:
# Processed file: resolved_Model2_1_MW_DWDs_aa2CE_NSWDs_aa2CE_vkick.h5
# Processed file: resolved_Model2_2_MW_DWDs_aa2CE_NSWDs_aa2CE_akick.h5
# Processed file: resolved_Model3_1_MW_DWDs_agCE_NSWDs_agCE_vkick.h5
# Processed file: resolved_Model3_0_MW_DWDs_agCE.h5
# Processed file: resolved_Model1_1_MW_DWDs_aaCE_NSWDs_aaCE_vkick.h5
# Processed file: resolved_Model1_0_MW_DWDs_aaCE.h5
# Processed file: resolved_Model1_2_MW_DWDs_aaCE_NSWDs_aaCE_akick.h5
# Processed file: resolved_Model2_4_MW_DWDs_aa2CE_NSWDs_aa2CE_bkick.h5
# Processed file: resolved_Model1_4_MW_DWDs_aaCE_NSWDs_aaCE_bkick.h5
# Processed file: resolved_Model2_3_MW_DWDs_aa2CE_NSWDs_aa2CE_hkick.h5
# Processed file: resolved_Model1_3_MW_DWDs_aaCE_NSWDs_aaCE_hkick.h5

# %%
resolved_df_clean = resolved_df[
    # keep every non-MW_DWD row…
    ~resolved_df['Name'].str.startswith('MW_DWD')
    # …and for MW_DWD rows only keep the first of each Name
    | ~resolved_df.duplicated(subset='Name')
].reset_index(drop=True)

# %%
selected_features = [
    'Frequency_mHz', 
    'Amplitude_log10', 
    'FrequencyDerivative_log10', 
    'SNR', 
    'Eccentricity',
    'EclipticLatitude_sin',
    'Inclination_cos',
    'Polarization',
    'EclipticLongitude',
    'InitialPhase'
]

X = resolved_df_clean[selected_features]
y = resolved_df_clean['Class']  # Assuming 'Class' is already 0 or 1.

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1, stratify=y 
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.2, random_state=1, stratify=y_train_val
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_val_scaled = scaler.transform(X_val)
joblib.dump(scaler, 'scaler_knn.pkl')
from skopt             import BayesSearchCV
from skopt.space       import Real, Categorical, Integer
from sklearn.svm       import SVC
from sklearn.metrics   import make_scorer, matthews_corrcoef
import joblib

# 1) Define your base SVM (without fixed hyper-params)
base_svc = SVC(
    probability=True,
    random_state=42,
    cache_size=2000,  # increase if you have the RAM
)

# 2) Wrap MCC (or swap to 'roc_auc' for AUC) as the scoring
mcc_scorer = make_scorer(matthews_corrcoef)

# 3) Specify the search space
search_spaces = {
    # Penalty parameter C: log-uniform from 1e-3 to 1e3
    'C':        Real(1e-3, 1e3, prior='log-uniform'),
}

# 4) Set up BayesSearchCV
opt_svc = BayesSearchCV(
    estimator=base_svc,
    search_spaces=search_spaces,
    scoring=mcc_scorer,
    cv=3,               # 3-fold CV
    n_iter=20,          # 30 hyper-param trials
    n_jobs=-1,
    refit=True,         # refit best model on the whole train set
    random_state=42,
    verbose=1
)

# 5) Run the search on your scaled training data
opt_svc.fit(X_train_scaled, y_train)

# 6) Inspect best parameters & best CV score
print("Best params:", opt_svc.best_params_)
print("Best CV MCC:", opt_svc.best_score_)

# 7) The best estimator is already refit on X_train_scaled
best_svc = opt_svc.best_estimator_

# 8) Save it for later
joblib.dump(best_svc, 'svm_model.pkl')
# Make predictions on the test set.
y_pred = best_svc.predict(X_val_scaled)

# Evaluate the classifier.
accuracy = accuracy_score(y_val, y_pred)
report = classification_report(y_val, y_pred)
conf_matrix = confusion_matrix(y_val, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# ...

# %% [markdown]
#  # Bayesian Calibration

# %%
from sklearn.neighbors import KernelDensity
scores_calib = best_svc.predict_proba(X_val_scaled)[:, 1]  # for positive class
s_pos = scores_calib[y_val == 1]
s_neg = scores_calib[y_val == 0]

# Fit KDE for each
kde_pos = KernelDensity(bandwidth=0.05).fit(s_pos[:, None])
kde_neg = KernelDensity(bandwidth=0.05).fit(s_neg[:, None])

# Empirical priors
prior_pos = np.mean(y_val == 1)
prior_neg = 1 - prior_pos

from scipy.signal import savgol_filter

# 1. grid
s_grid = np.linspace(0,1,200)[:, None]

# 2. raw densities
log_p_pos = kde_pos.score_samples(s_grid)
log_p_neg = kde_neg.score_samples(s_grid)
p_pos = np.exp(log_p_pos)
p_neg = np.exp(log_p_neg)

# 3. smooth
p_pos_smooth = savgol_filter(p_pos, window_length=21, polyorder=3)
p_neg_smooth = savgol_filter(p_neg, window_length=21, polyorder=3)

numer = p_pos_smooth * prior_pos
denom = numer + p_neg_smooth * prior_neg
posterior_grid = numer / denom

from scipy.interpolate import interp1d

calibrator = interp1d(
    s_grid.ravel(), 
    posterior_grid, 
    kind="linear", 
    bounds_error=False, 
    fill_value=(0.0, 1.0)
)

# Now calibrate test‐set scores:
scores_test = best_svc.predict_proba(X_test_scaled)[:, 1]
calibrated_probs = calibrator(scores_test)

# %%
from scipy.stats import gaussian_kde
prob_pos = calibrated_probs[y_test == 1]
prob_neg = calibrated_probs[y_test == 0]

kde_cpos = gaussian_kde(prob_pos)
kde_cneg = gaussian_kde(prob_neg)
x = np.linspace(0,1,200)

plt.figure()
plt.plot(x, kde_cpos(x), label='Positive class')
#plt.plot(x, kde_cneg(x), label='Negative class')
plt.xlabel('Calibrated probability')
plt.ylabel('Density')
plt.title('KDE of Calibrated Probabilities')
plt.legend()
plt.show()

# %%
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_auc_score, matthews_corrcoef, recall_score
)
def find_best_mcc_threshold(probs, y_true, n_steps=1001):
    # 1) Create a grid of thresholds in [0,1]
    thresholds = np.linspace(0, 1, n_steps)
    mccs = np.empty_like(thresholds)

    # 2) Compute MCC at each threshold
    for i, t in enumerate(thresholds):
        y_pred = (probs > t).astype(int)
        mccs[i] = matthews_corrcoef(y_true, y_pred)

    # 3) Pick best
    best_idx = np.argmax(mccs)
    return thresholds[best_idx], mccs[best_idx], thresholds, mccs

# ─── Usage ────────────────────────────────────────────────────────────
# probs   = your array of predicted probabilities
# y_true  = your true labels (0/1)

best_t, best_mcc, t_grid, mcc_grid = find_best_mcc_threshold(calibrated_probs, y_test)

print(f"Optimal threshold: {best_t:.3f}  →  MCC = {best_mcc:.3f}")

# ─── (Optional) Plot MCC vs threshold ────────────────────────────────
plt.figure(figsize=(6,4))
plt.plot(t_grid, mcc_grid, '-')
plt.axvline(best_t, color='red', linestyle='--',
            label=f'best t = {best_t:.3f}')
plt.xlabel('Decision threshold')
plt.ylabel('MCC')
plt.title('MCC as a function of threshold')
plt.legend()
plt.show()
# Out:
# Optimal threshold: 0.560  →  MCC = 0.852

# %%
# ─── 2) Threshold at 0.5 to get predicted labels ────────────────

y_pred = (calibrated_probs > 0.560).astype(int)

# ─── 3) Confusion matrix and plot ────────────────────────────────
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])

fig, ax = plt.subplots(figsize=(5,5))
disp.plot(ax=ax, cmap='Blues')
plt.title("Confusion Matrix (threshold = 0.5)")
plt.show()

# ─── 4) Compute metrics ───────────────────────────────────────────
# Sensitivity = Recall for the positive class
sensitivity = recall_score(y_test, y_pred, pos_label=1)

# Specificity = Recall for the negative class
specificity = recall_score(y_test, y_pred, pos_label=0)

# AUROC uses the raw probabilities
auroc = roc_auc_score(y_test, calibrated_probs)

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, y_pred)

print(f"Sensitivity (TPR) : {sensitivity:.3f}")
print(f"Specificity (TNR) : {specificity:.3f}")
print(f"AUROC             : {auroc:.3f}")
print(f"MCC               : {mcc:.3f}")
# Out:
# Sensitivity (TPR) : 0.776
# Specificity (TNR) : 0.998
# AUROC             : 0.988
# MCC               : 0.852
